# %%
import pandas as pd
import pyecharts.charts as pye
import pyecharts.options as opts
from IPython.display import HTML

# %%
df = pd.read_csv('athlete_events.csv')

df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
plot = (pye.WordCloud()
        .add(series_name='', 
             word_size_range=[10, 75],
             data_pair=[(k, v) for k, v in df['Sport'].value_counts().to_dict().items()]
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(
                title="Word Cloud of All Olympics sport programs", 
            ),
        )
        )

plot.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="84c61173fb26481e9df1fa6e14e6d47a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_84c61173fb26481e9df1fa6e14e6d47a = echarts.init(
#                     document.getElementById('84c61173fb26481e9df1fa6e14e6d47a'), 'white', {renderer: 'canvas'});
#                 var option_84c61173fb26481e9df1fa6e14e6d47a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
# ...

# %%
plot.render('Word Cloud of All Olympics sport programs.html')

# %% [markdown]
# <div>
# <img src="download.png" width="1000"/>
# </div>

# %%
data = df.groupby(['Sex', 'Year']).mean().reset_index()[['Sex', 'Year', 'Age']].sort_values(by='Year')
plot = (pye.Line()
        .add_xaxis(list(data['Year'].astype(str).unique()))
        .add_yaxis('Female Age', data.loc[data['Sex']=='F', 'Age'].astype(int).to_list(), is_smooth=True)
        .add_yaxis('Male Age', data.loc[data['Sex']=='M', 'Age'].astype(int).to_list(), is_smooth=True)
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Average Age Over Year"),
            xaxis_opts=opts.AxisOpts(name="Year"),
            yaxis_opts=opts.AxisOpts(
                name="Average Age",
                splitline_opts=opts.SplitLineOpts(is_show=True),
                is_scale=True,
            ),
        )
        )

plot.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9f841e838fd540aebe2c0cda959de362" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9f841e838fd540aebe2c0cda959de362 = echarts.init(
#                     document.getElementById('9f841e838fd540aebe2c0cda959de362'), 'white', {renderer: 'canvas'});
#                 var option_9f841e838fd540aebe2c0cda959de362 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
plot.render('Average Age Over Year.html')

# %% [markdown]
# <div>
# <img src="download (1).png" width="1000"/>
# </div>

# %%
data = df.loc[df['Medal']=='Gold', ['Team', 'Medal']].groupby(['Team']).count().reset_index().sort_values(by='Medal')[-10:]
plot = (pye.Bar()
        .add_xaxis(data['Team'].to_list())
        .add_yaxis('Gold Medal', data['Medal'].to_list())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Top 10 Teams with most gold medals"),
            xaxis_opts=opts.AxisOpts(name="Team", axislabel_opts=opts.LabelOpts(rotate=-15)),
            yaxis_opts=opts.AxisOpts(
                name="Total Gold Medal",
                splitline_opts=opts.SplitLineOpts(is_show=True),
                is_scale=True,
            ),
        )
        )

plot.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="58a4c57c9761435f942b5c414c1bd706" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_58a4c57c9761435f942b5c414c1bd706 = echarts.init(
#                     document.getElementById('58a4c57c9761435f942b5c414c1bd706'), 'white', {renderer: 'canvas'});
#                 var option_58a4c57c9761435f942b5c414c1bd706 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
plot.render('Top 10 Teams with most gold medals.html')

# %% [markdown]
# <div>
# <img src="download (2).png" width="1000"/>
# </div>

# %%
data = (df.loc[(df['Team']=='China') & (df['Medal']=='Gold'), ['Sport', 'Medal']]
        .groupby(['Sport']).count().reset_index()
        .sort_values(by='Medal')[-10:])
plot = (pye.Funnel(init_opts=opts.InitOpts(width="1000px"))
        .add('China Gold Medal', [[i.Sport, i.Medal] for i in data.itertuples()],
             label_opts=opts.LabelOpts(is_show=True, position="inside"),)
        .set_global_opts(
            title_opts=opts.TitleOpts(title="China's Top 10 Sport with most gold medals"),
            legend_opts=opts.LegendOpts(type_="scroll", pos_top='30%', pos_left="right", orient="vertical"),
        )
        )

plot.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="58ca6520d69b4cea8710b477b4adf3cd" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_58ca6520d69b4cea8710b477b4adf3cd = echarts.init(
#                     document.getElementById('58ca6520d69b4cea8710b477b4adf3cd'), 'white', {renderer: 'canvas'});
#                 var option_58ca6520d69b4cea8710b477b4adf3cd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
plot.render('China\'s Top 10 Sport with most gold medals.html')

# %% [markdown]
# <div>
# <img src="download (3).png" width="1000"/>
# </div>
