# %%
import pandas as pd
import pyecharts.charts as pye
import pyecharts.options as opts

# %%
df = pd.read_csv('athlete_events.csv')

df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
plot = (pye.WordCloud()
        .add(series_name='', 
             word_size_range=[10, 75],
             data_pair=[(k, v) for k, v in df['Sport'].value_counts().to_dict().items()]
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(
                title="Word Cloud of All Olympics sport programs", 
            ),
        )
        )

plot.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="ebc215ada13e4e83aabd5086b2fa69d2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_ebc215ada13e4e83aabd5086b2fa69d2 = echarts.init(
#                     document.getElementById('ebc215ada13e4e83aabd5086b2fa69d2'), 'white', {renderer: 'canvas'});
#                 var option_ebc215ada13e4e83aabd5086b2fa69d2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
# ...

# %%
data = df.groupby(['Year']).mean().reset_index()[['Year', 'Age']]
plot = (pye.Line()
        .add_xaxis(data['Year'].astype(str).to_list())
        .add_yaxis('', data['Age'].astype(int).to_list())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Average Age Over Year"),
            xaxis_opts=opts.AxisOpts(name="Year"),
            yaxis_opts=opts.AxisOpts(
                name="Average Age",
                splitline_opts=opts.SplitLineOpts(is_show=True),
                is_scale=True,
            ),
        )
        )

plot.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c4578c8584d64d9da47ee57f2353da7e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c4578c8584d64d9da47ee57f2353da7e = echarts.init(
#                     document.getElementById('c4578c8584d64d9da47ee57f2353da7e'), 'white', {renderer: 'canvas'});
#                 var option_c4578c8584d64d9da47ee57f2353da7e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
